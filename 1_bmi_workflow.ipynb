# %%
from langgraph.graph import StateGraph, START,END
from typing import TypedDict
from IPython.display import Image

# %%
# Define state

class BMIState(TypedDict):
    weight_kg : float
    height_m : float
    bmi : float

# %%
# Define graph
graph = StateGraph(BMIState)

# %%
def calculate_bmi(state:BMIState) -> BMIState:
    weight = state['weight_kg']
    height = state['height_m']

    bmi = weight / (height ** 2)

    state['bmi'] = bmi

    return state

# %%
# # Add nodes
graph.add_node('calculate_bmi',calculate_bmi)



# Add edges
graph.add_edge(START,'calculate_bmi')
graph.add_edge('calculate_bmi',END)



#compile graph
workflow = graph.compile()



# Execute graph
initial_state = {'weight_kg':80,'height_m':1.73}
final_state = workflow.invoke(initial_state)



print(final_state)
# Out:
# {'weight_kg': 80, 'height_m': 1.73, 'bmi': 26.729927495071667}

# %%
#Displaying the graph
print(workflow.get_graph().draw_ascii())
# Out:
#   +-----------+
#   | __start__ |
#   +-----------+
#         *
#         *
#         *
# +---------------+
# | calculate_bmi |
# +---------------+
#         *
#         *
#         *
#    +---------+
#    | __end__ |
#    +---------+

# %%
Image(workflow.get_graph().draw_png())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 Image(workflow.get_graph().draw_png())
#
# File c:\Users\H604660\Desktop\Siddhi Shintre\My Learnings\LANGGRAPH\myenv\Lib\site-packages\langchain_core\runnables\graph.py:573, in Graph.draw_png(self, output_file_path, fontname, labels)
#     560 from langchain_core.runnables.graph_png import PngDrawer  # noqa: PLC0415
#     562 default_node_labels = {node.id: node.name for node in self.nodes.values()}
#     564 return PngDrawer(
#     565     fontname,
#     566     LabelsDict(
#     567         nodes={
#     568             **default_node_labels,
#     569             **(labels["nodes"] if labels is not None else {}),
#     570         },
#     571         edges=labels["edges"] if labels is not None else {},
#     572     ),
# --> 573 ).draw(self, output_file_path)
#
# File c:\Users\H604660\Desktop\Siddhi Shintre\My Learnings\LANGGRAPH\myenv\Lib\site-packages\langchain_core\runnables\graph_png.py:137, in PngDrawer.draw(self, graph, output_path)
#     135 if not _HAS_PYGRAPHVIZ:
#     136     msg = "Install pygraphviz to draw graphs: `pip install pygraphviz`."
# --> 137     raise ImportError(msg)
#     139 # Create a directed graph
#     140 viz = pgv.AGraph(directed=True, nodesep=0.9, ranksep=1.0)
#
# ImportError: Install pygraphviz to draw graphs: `pip install pygraphviz`.
